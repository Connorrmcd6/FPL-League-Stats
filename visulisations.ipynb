# %%
import pandas as pd
import plotly.express as px
from functions import *

# %%
data = create_league_dict(league_id)

# %%
print(data)
# Out:
# {'Marco Gouveia': {'points': [105, 78, 62, 66, 69, 52, 38, 59, 93, 40, 76, 62, 52, 64, 42, 59, 79, 50, 63, 32, 68, 55, 32, 85, 62], 'cumulative_points': [105, 183, 245, 307, 376, 424, 462, 521, 614, 650, 726, 788, 840, 900, 942, 1001, 1076, 1126, 1189, 1221, 1289, 1340, 1372, 1457, 1515], 'gw_rank': [151567, 485894, 2253573, 2077179, 1150257, 1671711, 4122687, 1701265, 876814, 4967130, 34441, 3283188, 2391000, 3472943, 4473091, 3807899, 76656, 2360404, 416570, 5753162, 1182293, 3567941, 5270300, 365373, 1643610], 'overall_rank': [151566, 118862, 174197, 236050, 141917, 155939, 224636, 199450, 146498, 254843, 114256, 162054, 171114, 209932, 254343, 311556, 202214, 220876, 145191, 183629, 187940, 223995, 235959, 178084, 191994], 'gw_transfers': [0, 0, 2, 2, 1, 2, 1, 0, 1, 2, 1, 1, 1, 2, 0, 2, 2, 1, 0, 1, 1, 2, 0, 2, 2], 'hits': [0, 0, 0, 4, 0, 4, 0, 0, 0, 4, 0, 0, 0, 4, 0, 0, 4, 0, 0, 0, 0, 4, 0, 0, 4], 'points_on_bench': [9, 3, 8, 4, 13, 9, 8, 7, 23, 25, 21, 21, 0, 7, 7, 0, 0, 0, 4, 0
# ...

# %%
managers = []
for i in data:
    managers.append(i)

# %%
for i in managers:
    print(data[i])
